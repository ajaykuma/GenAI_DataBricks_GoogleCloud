# %%
# !pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-text-splitters) (1.2.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.11.10)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.3.1)

# %%
import langchain
import langchain_core
import langchain_text_splitters

print(langchain.__version__)
print(langchain_core.__version__)
# Out:
# 1.2.0
# 1.2.4

# %%
from langchain_text_splitters import (
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter,
    TokenTextSplitter,SentenceTransformersTokenTextSplitter
)

# %%
#Character-based splitter
text = """Hopefully, you’ve seen the pattern that most
decision-making requires multiple data points and
types to make decisions. AI agents are replacing
manual data stitching with automated, accurate
insights — boosting productivity and enabling faster
strategic decisions that ultimately will help unlock
new revenue opportunities. Here is one thing to keep
in mind as you start the journey to give employees
a decision intelligence agent: delivering accurate
answers while ensuring data privacy becomes
increasingly complex as more data sources are
connected and more AI agents are built on top of
them. To address this from the start, it's important
to evaluate solutions with a platform mindset where
shared data governance, processing and retrieval
resources drive cost-efficiencies."""

# %%
splitter = CharacterTextSplitter(
    separator=".",
    chunk_size=10,
    chunk_overlap=0,
)
chunks = splitter.split_text(text)
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 118, which is longer than the specified 10
# WARNING:langchain_text_splitters.base:Created a chunk of size 203, which is longer than the specified 10
# WARNING:langchain_text_splitters.base:Created a chunk of size 272, which is longer than the specified 10

# %%
type(chunks)
# Out:
# list

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully, you’ve seen the pattern that most
# decision-making requires multiple data points and
# types to make decisions
# 1 AI agents are replacing
# manual data stitching with automated, accurate
# insights — boosting productivity and enabling faster
# strategic decisions that ultimately will help unlock
# new revenue opportunities
# 2 Here is one thing to keep
# in mind as you start the journey to give employees
# a decision intelligence agent: delivering accurate
# answers while ensuring data privacy becomes
# increasingly complex as more data sources are
# connected and more AI agents are built on top of
# them
# 3 To address this from the start, it's important
# to evaluate solutions with a platform mindset where
# shared data governance, processing and retrieval
# resources drive cost-efficiencies

# %%
#Recursive splitter
splitter = RecursiveCharacterTextSplitter(
    chunk_size=7,
    chunk_overlap=2,
)
chunks = splitter.split_text(text)

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopeful
# 1 ully,
# 2 you’ve
# 3 seen
# 4 the
# 5 patter
# 6 ern
# 7 that
# 8 most
# 9 decisi
# 10 sion-ma
# 11 making
# 12 requir
# 13 ires
# 14 multip
# 15 iple
# 16 data
# 17 points
# 18 and
# 19 types
# 20 to
# 21 make
# 9 decisi
# 23 sions.
# 24 AI
# 25 agents
# 26 are
# 27 replac
# 28 acing
# 29 manual
# 16 data
# 31 stitch
# 32 ching
# 33 with
# 34 automa
# 35 mated,
# 36 accura
# 37 rate
# 38 insigh
# 39 ghts
# 40 —
# 41 boosti
# 42 ting
# 43 produc
# 44 uctivit
# 45 ity
# 18 and
# 47 enabli
# 48 ling
# 49 faster
# 50 strate
# 51 tegic
# 9 decisi
# 53 sions
# 7 that
# 55 ultima
# 56 mately
# 57 will
# 58 help
# 59 unlock
# 60 new
# 61 revenu
# 62 nue
# 63 opport
# 64 rtuniti
# 65 ties.
# 66 Here
# 67 is one
# 68 thing
# 20 to
# 70 keep
# 71 in
# 72 mind
# 73 as you
# 74 start
# 4 the
# 76 journe
# 77 ney
# 20 to
# 79 give
# 80 employ
# 81 oyees
# 82 a
# 9 decisi
# 84 sion
# 85 intell
# 86 lligenc
# 87 nce
# 88 agent:
# 89 delive
# 90 vering
# 36 accura
# 37 rate
# 93 answer
# 94 ers
# 95 while
# 96 ensuri
# 97 ring
# 16 data
# 99 privac
# 100 acy
# 101 become
# 102 mes
# 103 increa
# 104 easingl
# 105 gly
# 106 comple
# 107 lex
# 108 as
# 109 more
# 16 data
# 111 source
# 112 ces
# 26 are
# 114 connec
# 115 ected
# 18 and
# 109 more
# 24 AI
# 25 agents
# 26 are
# 121 built
# 122 on top
# 123 of
# 124 them.
# 125 To
# 126 addres
# 127 ess
# 128 this
# 129 from
# 4 the
# 131 start,
# 132 it's
# 133 import
# 134 rtant
# 20 to
# 136 evalua
# 137 uate
# 138 soluti
# 139 tions
# 140 with a
# 141 platfo
# 142 form
# 143 mindse
# 144 set
# 145 where
# 146 shared
# 16 data
# 148 govern
# 149 rnance,
# 150 proces
# 151 essing
# 18 and
# 153 retrie
# 154 ieval
# 155 resour
# 156 urces
# 157 drive
# 158 cost-e
# 159 -effici
# 160 ciencie
# 161 ies.

# %%
#Recursive splitter
splitter = RecursiveCharacterTextSplitter(
    chunk_size=7,
    chunk_overlap=2,
    separators=[" "]
)
chunks = splitter.split_text(text)

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully,
# 1  you’ve
# 2 seen
# 3 the
# 4  pattern
# 5 that
# 6  most
# decision-making
# 7  requires
# 8  multiple
# 9 data
# 10  points
# 11  and
# types
# 12 to
# 13 make
# 14  decisions.
# 15 AI
# 16  agents
# 17 are
# 18  replacing
# manual
# 9 data
# 20  stitching
# 21 with
# 22  automated,
# 23  accurate
# insights
# 24 —
# 25  boosting
# 26  productivity
# 27 and
# 28  enabling
# 29  faster
# strategic
# 30  decisions
# 5 that
# 32  ultimately
# 33 will
# 34 help
# 35  unlock
# new
# 36  revenue
# 37  opportunities.
# 38 Here
# 39 is one
# 40 thing
# 12 to
# 42  keep
# in
# 43 mind
# 44 as you
# 45 start
# 3 the
# 47  journey
# 12 to
# 49 give
# 50  employees
# a
# 51  decision
# 52  intelligence
# 53  agent:
# 54  delivering
# 55  accurate
# answers
# 56 while
# 57  ensuring
# 9 data
# 59  privacy
# 60  becomes
# increasingly
# 61  complex
# 62 as
# 63 more
# 9 data
# 65  sources
# 66  are
# connected
# 27 and
# 63 more
# 15 AI
# 16  agents
# 17 are
# 72 built
# 73 on top
# 74  of
# them.
# 75 To
# 76  address
# 77 this
# 78 from
# 3 the
# 80  start,
# 81 it's
# 82  important
# to
# 83  evaluate
# 84  solutions
# 85 with a
# 86  platform
# 87  mindset
# 88  where
# shared
# 9 data
# 90  governance,
# 91  processing
# 27 and
# 93  retrieval
# resources
# 94 drive
# 95  cost-efficiencies.

# %%
splitter = CharacterTextSplitter(
    separator=".",
    chunk_size=150,
    chunk_overlap=10,
)
chunks = splitter.split_text(text)
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 203, which is longer than the specified 150
# WARNING:langchain_text_splitters.base:Created a chunk of size 272, which is longer than the specified 150

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully, you’ve seen the pattern that most
# decision-making requires multiple data points and
# types to make decisions
# 1 AI agents are replacing
# manual data stitching with automated, accurate
# insights — boosting productivity and enabling faster
# strategic decisions that ultimately will help unlock
# new revenue opportunities
# 2 Here is one thing to keep
# in mind as you start the journey to give employees
# a decision intelligence agent: delivering accurate
# answers while ensuring data privacy becomes
# increasingly complex as more data sources are
# connected and more AI agents are built on top of
# them
# 3 To address this from the start, it's important
# to evaluate solutions with a platform mindset where
# shared data governance, processing and retrieval
# resources drive cost-efficiencies

# %%
splitter = SentenceTransformersTokenTextSplitter(
    model_name="sentence-transformers/all-mpnet-base-v2",
    chunk_size=150,
    chunk_overlap=20,
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
chunks = splitter.split_text(text)

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 hopefully, you ’ ve seen the pattern that most decision - making requires multiple data points and types to make decisions. ai agents are replacing manual data stitching with automated, accurate insights — boosting productivity and enabling faster strategic decisions that ultimately will help unlock new revenue opportunities. here is one thing to keep in mind as you start the journey to give employees a decision intelligence agent : delivering accurate answers while ensuring data privacy becomes increasingly complex as more data sources are connected and more ai agents are built on top of them. to address this from the start, it ' s important to evaluate solutions with a platform mindset where shared data governance, processing and retrieval resources drive cost - efficiencies.

# %%
#Token-aware splitter
splitter = TokenTextSplitter(chunk_size=100, chunk_overlap=10)
tokens = splitter.split_text(text)

# %%
for i in tokens:
  print(tokens.index(i),i)
# Out:
# 0 Hopefully, you’ve seen the pattern that most
# decision-making requires multiple data points and
# types to make decisions. AI agents are replacing
# manual data stitching with automated, accurate
# insights — boosting productivity and enabling faster
# strategic decisions that ultimately will help unlock
# new revenue opportunities. Here is one thing to keep
# in mind as you start the journey to give employees
# a decision intelligence agent: delivering accurate
# answers while ensuring data privacy becomes
# increasingly
# 1 wers while ensuring data privacy becomes
# increasingly complex as more data sources are
# connected and more AI agents are built on top of
# them. To address this from the start, it's important
# to evaluate solutions with a platform mindset where
# shared data governance, processing and retrieval
# resources drive cost-efficiencies.

# %%
from langchain_core.documents import Document

docs = [Document(page_content=text, metadata={})]
split_docs = splitter.split_documents(docs)

# %%
for i in split_docs:
  print(split_docs.index(i),i)
# Out:
# 0 page_content='Hopefully, you’ve seen the pattern that most
# decision-making requires multiple data points and
# types to make decisions. AI agents are replacing
# manual data stitching with automated, accurate
# insights — boosting productivity and enabling faster
# strategic decisions that ultimately will help unlock
# new revenue opportunities. Here is one thing to keep
# in mind as you start the journey to give employees
# a decision intelligence agent: delivering accurate
# answers while ensuring data privacy becomes
# increasingly'
# 1 page_content='wers while ensuring data privacy becomes
# increasingly complex as more data sources are
# connected and more AI agents are built on top of
# them. To address this from the start, it's important
# to evaluate solutions with a platform mindset where
# shared data governance, processing and retrieval
# resources drive cost-efficiencies.'

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
model = "sentence-transformers/all-MiniLM-L6-v2"

# %%
embeddings = HuggingFaceEmbeddings(model_name=model)
# Out:
# /tmp/ipython-input-2590713520.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name=model)
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
text = "tell me something about langchain"

# %%
test_embedding = embeddings.embed_documents(text)

# %%
print(test_embedding)
# Out:
# [[-0.05895747244358063, 0.05387331172823906, 0.008316769264638424, 0.020680487155914307, 0.0022009573876857758, -0.03443438187241554, 0.08473184704780579, 0.10776817798614502, 0.05895739421248436, -0.016638686880469322, 0.06211813911795616, -0.0740492194890976, -0.030303165316581726, 0.03807588666677475, -0.004251436796039343, -0.007986406795680523, 0.0031452819239348173, -0.07220276445150375, -0.015011955052614212, -0.0713619589805603, -0.08817404508590698, 0.04520193114876747, 0.009071126580238342, 0.04195646196603775, -0.0012928919168189168, -0.014840217307209969, -0.03942640870809555, 0.0070774145424366, -0.036413609981536865, -0.04289926588535309, -0.04982231557369232, 0.009418332017958164, -0.02269922010600567, 0.01023806817829609, -0.004453885369002819, -0.07801613211631775, -0.07069578766822815, -0.005806335713714361, 0.03875806927680969, 0.012042314745485783, -0.05325382947921753, -0.09637933224439621, -0.02809724025428295, -0.00988376047462225, 0.06731415539979935, 0.004278326407074928, 0.02124863862991333, -0.02291441522538662, -0.06625283509492874, -0.023488439619541168, 4.1625571611803025e-05, 0.009640544652938843, -0.03294277936220169, 0.014496290124952793, 0.018593713641166687, 0.047485269606113434, -0.012361094355583191